# %%
from bs4 import BeautifulSoup
import requests
import re

# %% [markdown]
# ### Helper functions

# %%
def scrapeText(url: str, currentPage: int):

    completeText = ''
    
    while (currentPage):
        if currentPage == 1:
            currentUrl = requests.get(url.format('')).text
        else:
            currentUrl = requests.get(url.format('_' + str(currentPage))).text
 
        soup = BeautifulSoup(currentUrl, 'lxml')

        if '404' in soup.find('title').text or '301' in soup.find('title').text:
            break
        
        textDiv = soup.find('div', {'class': 'text'})
        paragraphs = textDiv.find_all('p')
        
        for sentence in paragraphs:
            completeText += sentence.text + '%'
        
        print('Page No. ' + str(currentPage) + ': ' + str(len(paragraphs)) + ' paragraphs')
        currentPage += 1
        
    return completeText

def cleanText(text, removeUntil):
    if len(removeUntil) > 0:
        text = re.sub(fr'.*(?<={removeUntil})', '', text)
        
    # 1. Split in paragraphs to filter headings, chapter numbers etc.
    
    paragraphs = text.split('%')
    paragraphs = [re.sub(r'^Chapter [0-9]+|([A-Z|\s|-]+)$', '', el) for el in paragraphs]
    text = ''.join(paragraphs)
   
    # 2. Escape in-text colons temporarily
    
    text = text.replace('S.R.', 'S#R#')
    text = text.replace('F.A.', 'F#A#')
    text = text.replace('Mr.', 'Mr#')
    text = text.replace('Mrs.', 'Mrs#')
    text = text.replace('S.-B.', 'S#-B#')
        
    # 3. Replace some stuff and split into single sentences
    
    text = text.replace('’', '')
    text = text.replace('‘', '')
    text = text.replace('(', '')
    text = text.replace(')', '')
    text = text.replace('“', '')
    text = text.replace('”', '')

    splitted = text.split('.')
    splitted = [el.strip() for el in splitted]
    splitted = [el.replace('S#R#', 'S.R.') for el in splitted]
    splitted = [el.replace('F#A#', 'F.A.') for el in splitted]
    splitted = [el.replace('Mr#', 'Mr.') for el in splitted]
    splitted = [el.replace('Mrs#', 'Mrs.') for el in splitted]
    splitted = [el.replace('S#-B#', 'S.-B.') for el in splitted]
    splitted = [el for el in splitted if el]
    
    return splitted

# %% [markdown]
# ### Scrape and preprocess texts

# %%
lotr1Raw = scrapeText('https://thefreebooksonline.net/classics/u5691{}.html', 7)
lotr2Raw = scrapeText('https://thefreebooksonline.net/classics/u5690{}.html', 1)
lotr3Raw = scrapeText('https://thefreebooksonline.net/classics/u5689{}.html', 2)
hobbitRaw = scrapeText('https://thefreebooksonline.net/classics/u5688{}.html', 1)
silmarillionRaw = scrapeText('https://thefreebooksonline.net/classics/u5687{}.html', 1)
# Out:
# Page No. 7: 16 paragraphs
# Page No. 8: 19 paragraphs
# Page No. 9: 24 paragraphs
# Page No. 10: 12 paragraphs
# Page No. 11: 17 paragraphs
# Page No. 12: 33 paragraphs
# Page No. 13: 31 paragraphs
# Page No. 14: 25 paragraphs
# Page No. 15: 33 paragraphs
# Page No. 16: 25 paragraphs
# Page No. 17: 25 paragraphs
# Page No. 18: 27 paragraphs
# Page No. 19: 21 paragraphs
# Page No. 20: 20 paragraphs
# Page No. 21: 23 paragraphs
# Page No. 22: 23 paragraphs
# Page No. 23: 25 paragraphs
# Page No. 24: 26 paragraphs
# Page No. 25: 20 paragraphs
# Page No. 26: 23 paragraphs
# Page No. 27: 22 paragraphs
# Page No. 28: 26 paragraphs
# Page No. 29: 24 paragraphs
# Page No. 30: 26 paragraphs
# Page No. 31: 36 paragraphs
# Page No. 32: 33 paragraphs
# Page No. 33: 22 paragraphs
# Page No. 34: 23 paragraphs
# Page No. 35: 25 paragraphs
# Page No. 36: 25 paragraphs
# Page No. 37: 28 paragraphs
# Page No. 38: 26 paragraphs
# Page No. 39: 24 paragraphs
# Page No. 40: 25 paragraphs
# Page No. 41: 19 paragraphs
# Page No. 42: 15 paragraphs
# Page No. 43: 26 paragraphs
# Page No. 44: 16 paragraphs
# Page No. 45: 24 paragraphs
# Page No. 46: 15 paragraphs
# Page No. 47: 13 paragraphs
# Page No. 48: 16 paragraphs
# Page No. 49: 20 paragraphs
# Page No. 50: 12 paragraphs
# Page No. 51: 18 paragraphs
# Page No. 52: 20 paragraphs
# Page No. 53: 17 paragraphs
# Page No. 54: 21 paragraphs
# Page No. 55: 24 paragraphs
# Page No. 56: 19 paragraphs
# Page No. 57: 17 paragraphs
# Page No. 58: 18 paragraphs
# Page No. 59: 32 paragraphs
# Page No. 60: 24 paragraphs
# Page No. 61: 31 paragraphs
# Page No. 62: 28 paragraphs
# Page No. 63: 27 paragraphs
# Page No. 64: 33 paragraphs
# Page No. 65: 20 paragraphs
# Page No. 66: 24 paragraphs
# Page No. 67: 23 paragraphs
# Page No. 68: 27 paragraphs
# Page No. 69: 22 paragraphs
# Page No. 70: 8 paragraphs
# Page No. 71: 22 paragraphs
# Page No. 72: 14 paragraphs
# Page No. 73: 22 paragraphs
# Page No. 74: 24 paragraphs
# Page No. 75: 17 paragraphs
# Page No. 76: 20 paragraphs
# Page No. 77: 20 paragraphs
# Page No. 78: 36 paragraphs
# Page No. 79: 26 paragraphs
# Page No. 80: 23 paragraphs
# Page No. 81: 24 paragraphs
# Page No. 82: 23 paragraphs
# Page No. 83: 24 paragraphs
# Page No. 84: 14 paragraphs
# Page No. 85: 25 paragraphs
# Page No. 86: 22 paragraphs
# Page No. 87: 16 paragraphs
# Page No. 88: 23 paragraphs
# Page No. 89: 21 paragraphs
# Page No. 90: 21 paragraphs
# Page No. 91: 19 paragraphs
# Page No. 92: 25 paragraphs
# Page No. 93: 22 paragraphs
# Page No. 94: 23 paragraphs
# Page No. 95: 20 paragraphs
# Page No. 96: 23 paragraphs
# Page No. 97: 24 paragraphs
# Page No. 98: 25 paragraphs
# Page No. 99: 29 paragraphs
# Page No. 100: 22 paragraphs
# Page No. 101: 22 paragraphs
# Page No. 102: 25 paragraphs
# Page No. 103: 27 paragraphs
# Page No. 104: 29 paragraphs
# Page No. 105: 24 paragraphs
# Page No. 106: 28 paragraphs
# Page No. 107: 31 paragraphs
# Page No. 108: 19 paragraphs
# Page No. 109: 23 paragraphs
# Page No. 110: 32 paragraphs
# Page No. 111: 21 paragraphs
# Page No. 112: 19 paragraphs
# Page No. 113: 17 paragraphs
# Page No. 114: 18 paragraphs
# Page No. 115: 21 paragraphs
# Page No. 116: 26 paragraphs
# Page No. 117: 23 paragraphs
# Page No. 118: 25 paragraphs
# Page No. 119: 27 paragraphs
# Page No. 120: 21 paragraphs
# Page No. 121: 23 paragraphs
# Page No. 122: 18 paragraphs
# Page No. 123: 26 paragraphs
# Page No. 124: 26 paragraphs
# Page No. 125: 17 paragraphs
# Page No. 126: 18 paragraphs
# Page No. 127: 23 paragraphs
# Page No. 128: 22 paragraphs
# Page No. 129: 24 paragraphs
# Page No. 130: 17 paragraphs
# Page No. 131: 24 paragraphs
# Page No. 132: 23 paragraphs
# Page No. 133: 17 paragraphs
# Page No. 134: 17 paragraphs
# Page No. 135: 16 paragraphs
# Page No. 136: 20 paragraphs
# Page No. 137: 18 paragraphs
# Page No. 138: 25 paragraphs
# Page No. 139: 22 paragraphs
# Page No. 140: 20 paragraphs
# Page No. 141: 20 paragraphs
# Page No. 142: 27 paragraphs
# Page No. 143: 24 paragraphs
# Page No. 144: 17 paragraphs
# Page No. 145: 28 paragraphs
# Page No. 146: 22 paragraphs
# Page No. 1: 30 paragraphs
# Page No. 2: 23 paragraphs
# Page No. 3: 25 paragraphs
# Page No. 4: 26 paragraphs
# Page No. 5: 34 paragraphs
# Page No. 6: 20 paragraphs
# Page No. 7: 29 paragraphs
# Page No. 8: 27 paragraphs
# Page No. 9: 26 paragraphs
# Page No. 10: 25 paragraphs
# Page No. 11: 28 paragraphs
# Page No. 12: 25 paragraphs
# Page No. 13: 25 paragraphs
# Page No. 14: 29 paragraphs
# Page No. 15: 24 paragraphs
# Page No. 16: 25 paragraphs
# Page No. 17: 23 paragraphs
# Page No. 18: 23 paragraphs
# Page No. 19: 24 paragraphs
# Page No. 20: 22 paragraphs
# Page No. 21: 29 paragraphs
# Page No. 22: 14 paragraphs
# Page No. 23: 18 paragraphs
# Page No. 24: 15 paragraphs
# Page No. 25: 14 paragraphs
# Page No. 26: 14 paragraphs
# Page No. 27: 16 paragraphs
# Page No. 28: 25 paragraphs
# Page No. 29: 18 paragraphs
# Page No. 30: 36 paragraphs
# Page No. 31: 28 paragraphs
# Page No. 32: 15 paragraphs
# Page No. 33: 25 paragraphs
# Page No. 34: 28 paragraphs
# Page No. 35: 26 paragraphs
# Page No. 36: 20 paragraphs
# Page No. 37: 28 paragraphs
# Page No. 38: 15 paragraphs
# Page No. 39: 26 paragraphs
# Page No. 40: 30 paragraphs
# Page No. 41: 24 paragraphs
# Page No. 42: 29 paragraphs
# Page No. 43: 26 paragraphs
# Page No. 44: 28 paragraphs
# Page No. 45: 24 paragraphs
# Page No. 46: 28 paragraphs
# Page No. 47: 36 paragraphs
# Page No. 48: 29 paragraphs
# Page No. 49: 35 paragraphs
# Page No. 50: 25 paragraphs
# Page No. 51: 23 paragraphs
# Page No. 52: 25 paragraphs
# Page No. 53: 11 paragraphs
# Page No. 54: 23 paragraphs
# Page No. 55: 32 paragraphs
# Page No. 56: 29 paragraphs
# Page No. 57: 24 paragraphs
# Page No. 58: 12 paragraphs
# Page No. 59: 20 paragraphs
# Page No. 60: 19 paragraphs
# Page No. 61: 28 paragraphs
# Page No. 62: 21 paragraphs
# Page No. 63: 14 paragraphs
# Page No. 64: 22 paragraphs
# Page No. 65: 30 paragraphs
# Page No. 66: 28 paragraphs
# Page No. 67: 22 paragraphs
# Page No. 68: 27 paragraphs
# Page No. 69: 25 paragraphs
# Page No. 70: 27 paragraphs
# Page No. 71: 24 paragraphs
# Page No. 72: 30 paragraphs
# Page No. 73: 23 paragraphs
# Page No. 74: 26 paragraphs
# Page No. 75: 30 paragraphs
# Page No. 76: 32 paragraphs
# Page No. 77: 25 paragraphs
# Page No. 78: 23 paragraphs
# Page No. 79: 18 paragraphs
# Page No. 80: 23 paragraphs
# Page No. 81: 14 paragraphs
# Page No. 82: 31 paragraphs
# Page No. 83: 20 paragraphs
# Page No. 84: 13 paragraphs
# Page No. 85: 23 paragraphs
# Page No. 86: 23 paragraphs
# Page No. 87: 18 paragraphs
# Page No. 88: 18 paragraphs
# Page No. 89: 10 paragraphs
# Page No. 90: 19 paragraphs
# Page No. 91: 26 paragraphs
# Page No. 92: 31 paragraphs
# Page No. 93: 15 paragraphs
# Page No. 94: 30 paragraphs
# Page No. 95: 18 paragraphs
# Page No. 96: 18 paragraphs
# Page No. 97: 18 paragraphs
# Page No. 98: 16 paragraphs
# Page No. 99: 25 paragraphs
# Page No. 100: 15 paragraphs
# Page No. 101: 29 paragraphs
# Page No. 102: 25 paragraphs
# Page No. 103: 28 paragraphs
# Page No. 104: 27 paragraphs
# Page No. 105: 32 paragraphs
# Page No. 106: 23 paragraphs
# Page No. 107: 21 paragraphs
# Page No. 108: 26 paragraphs
# Page No. 109: 18 paragraphs
# Page No. 110: 17 paragraphs
# Page No. 111: 22 paragraphs
# Page No. 112: 19 paragraphs
# Page No. 113: 25 paragraphs
# Page No. 114: 31 paragraphs
# Page No. 115: 19 paragraphs
# Page No. 116: 22 paragraphs
# Page No. 117: 15 paragraphs
# Page No. 118: 17 paragraphs
# Page No. 119: 23 paragraphs
# Page No. 120: 17 paragraphs
# Page No. 121: 24 paragraphs
# Page No. 122: 31 paragraphs
# Page No. 123: 20 paragraphs
# Page No. 2: 26 paragraphs
# Page No. 3: 15 paragraphs
# Page No. 4: 19 paragraphs
# Page No. 5: 26 paragraphs
# Page No. 6: 17 paragraphs
# Page No. 7: 26 paragraphs
# Page No. 8: 18 paragraphs
# Page No. 9: 21 paragraphs
# Page No. 10: 23 paragraphs
# Page No. 11: 22 paragraphs
# Page No. 12: 30 paragraphs
# Page No. 13: 26 paragraphs
# Page No. 14: 22 paragraphs
# Page No. 15: 26 paragraphs
# Page No. 16: 32 paragraphs
# Page No. 17: 21 paragraphs
# Page No. 18: 21 paragraphs
# Page No. 19: 19 paragraphs
# Page No. 20: 26 paragraphs
# Page No. 21: 20 paragraphs
# Page No. 22: 30 paragraphs
# Page No. 23: 31 paragraphs
# Page No. 24: 19 paragraphs
# Page No. 25: 17 paragraphs
# Page No. 26: 25 paragraphs
# Page No. 27: 26 paragraphs
# Page No. 28: 26 paragraphs
# Page No. 29: 18 paragraphs
# Page No. 30: 16 paragraphs
# Page No. 31: 21 paragraphs
# Page No. 32: 29 paragraphs
# Page No. 33: 20 paragraphs
# Page No. 34: 23 paragraphs
# Page No. 35: 22 paragraphs
# Page No. 36: 17 paragraphs
# Page No. 37: 22 paragraphs
# Page No. 38: 21 paragraphs
# Page No. 39: 18 paragraphs
# Page No. 40: 24 paragraphs
# Page No. 41: 23 paragraphs
# Page No. 42: 17 paragraphs
# Page No. 43: 26 paragraphs
# Page No. 44: 24 paragraphs
# Page No. 45: 27 paragraphs
# Page No. 46: 19 paragraphs
# Page No. 47: 25 paragraphs
# Page No. 48: 30 paragraphs
# Page No. 49: 22 paragraphs
# Page No. 50: 22 paragraphs
# Page No. 51: 18 paragraphs
# Page No. 52: 20 paragraphs
# Page No. 53: 14 paragraphs
# Page No. 54: 17 paragraphs
# Page No. 55: 18 paragraphs
# Page No. 56: 18 paragraphs
# Page No. 57: 12 paragraphs
# Page No. 58: 16 paragraphs
# Page No. 59: 18 paragraphs
# Page No. 60: 17 paragraphs
# Page No. 61: 23 paragraphs
# Page No. 62: 20 paragraphs
# Page No. 63: 26 paragraphs
# Page No. 64: 22 paragraphs
# Page No. 65: 16 paragraphs
# Page No. 66: 15 paragraphs
# Page No. 67: 28 paragraphs
# Page No. 68: 19 paragraphs
# Page No. 69: 20 paragraphs
# Page No. 70: 15 paragraphs
# Page No. 71: 18 paragraphs
# Page No. 72: 23 paragraphs
# Page No. 73: 15 paragraphs
# Page No. 74: 23 paragraphs
# Page No. 75: 20 paragraphs
# Page No. 76: 23 paragraphs
# Page No. 77: 23 paragraphs
# Page No. 78: 21 paragraphs
# Page No. 79: 28 paragraphs
# Page No. 80: 24 paragraphs
# Page No. 81: 24 paragraphs
# Page No. 82: 18 paragraphs
# Page No. 83: 23 paragraphs
# Page No. 84: 23 paragraphs
# Page No. 85: 23 paragraphs
# Page No. 86: 23 paragraphs
# Page No. 87: 25 paragraphs
# Page No. 88: 29 paragraphs
# Page No. 89: 20 paragraphs
# Page No. 90: 30 paragraphs
# Page No. 91: 19 paragraphs
# Page No. 92: 26 paragraphs
# Page No. 93: 37 paragraphs
# Page No. 94: 29 paragraphs
# Page No. 95: 31 paragraphs
# Page No. 96: 30 paragraphs
# Page No. 97: 33 paragraphs
# Page No. 98: 30 paragraphs
# Page No. 99: 22 paragraphs
# Page No. 100: 19 paragraphs
# Page No. 101: 27 paragraphs
# Page No. 102: 25 paragraphs
# Page No. 103: 27 paragraphs
# Page No. 104: 32 paragraphs
# Page No. 105: 28 paragraphs
# Page No. 106: 4 paragraphs
# Page No. 1: 15 paragraphs
# Page No. 2: 27 paragraphs
# Page No. 3: 27 paragraphs
# Page No. 4: 14 paragraphs
# Page No. 5: 19 paragraphs
# Page No. 6: 15 paragraphs
# Page No. 7: 28 paragraphs
# Page No. 8: 29 paragraphs
# Page No. 9: 19 paragraphs
# Page No. 10: 35 paragraphs
# Page No. 11: 38 paragraphs
# Page No. 12: 20 paragraphs
# Page No. 13: 24 paragraphs
# Page No. 14: 19 paragraphs
# Page No. 15: 17 paragraphs
# Page No. 16: 19 paragraphs
# Page No. 17: 22 paragraphs
# Page No. 18: 23 paragraphs
# Page No. 19: 34 paragraphs
# Page No. 20: 35 paragraphs
# Page No. 21: 29 paragraphs
# Page No. 22: 23 paragraphs
# Page No. 23: 26 paragraphs
# Page No. 24: 23 paragraphs
# Page No. 25: 18 paragraphs
# Page No. 26: 15 paragraphs
# Page No. 27: 22 paragraphs
# Page No. 28: 22 paragraphs
# Page No. 29: 25 paragraphs
# Page No. 30: 39 paragraphs
# Page No. 31: 19 paragraphs
# Page No. 32: 18 paragraphs
# Page No. 33: 12 paragraphs
# Page No. 34: 22 paragraphs
# Page No. 35: 21 paragraphs
# Page No. 36: 21 paragraphs
# Page No. 37: 16 paragraphs
# Page No. 38: 21 paragraphs
# Page No. 39: 20 paragraphs
# Page No. 40: 18 paragraphs
# Page No. 41: 17 paragraphs
# Page No. 42: 23 paragraphs
# Page No. 43: 15 paragraphs
# Page No. 44: 17 paragraphs
# Page No. 45: 21 paragraphs
# Page No. 46: 14 paragraphs
# Page No. 47: 16 paragraphs
# Page No. 48: 23 paragraphs
# Page No. 49: 15 paragraphs
# Page No. 50: 19 paragraphs
# Page No. 51: 18 paragraphs
# Page No. 52: 22 paragraphs
# Page No. 53: 18 paragraphs
# Page No. 54: 26 paragraphs
# Page No. 55: 21 paragraphs
# Page No. 56: 19 paragraphs
# Page No. 57: 21 paragraphs
# Page No. 58: 25 paragraphs
# Page No. 59: 24 paragraphs
# Page No. 60: 28 paragraphs
# Page No. 61: 20 paragraphs
# Page No. 62: 14 paragraphs
# Page No. 63: 29 paragraphs
# Page No. 64: 18 paragraphs
# Page No. 65: 31 paragraphs
# Page No. 66: 29 paragraphs
# Page No. 67: 35 paragraphs
# Page No. 68: 17 paragraphs
# Page No. 69: 17 paragraphs
# Page No. 70: 30 paragraphs
# Page No. 71: 25 paragraphs
# Page No. 72: 21 paragraphs
# Page No. 73: 23 paragraphs
# Page No. 74: 11 paragraphs
# Page No. 1: 11 paragraphs
# Page No. 2: 11 paragraphs
# Page No. 3: 14 paragraphs
# Page No. 4: 12 paragraphs
# Page No. 5: 11 paragraphs
# Page No. 6: 22 paragraphs
# Page No. 7: 13 paragraphs
# Page No. 8: 10 paragraphs
# Page No. 9: 13 paragraphs
# Page No. 10: 25 paragraphs
# Page No. 11: 15 paragraphs
# Page No. 12: 12 paragraphs
# Page No. 13: 13 paragraphs
# Page No. 14: 12 paragraphs
# Page No. 15: 15 paragraphs
# Page No. 16: 16 paragraphs
# Page No. 17: 12 paragraphs
# Page No. 18: 15 paragraphs
# Page No. 19: 14 paragraphs
# Page No. 20: 16 paragraphs
# Page No. 21: 18 paragraphs
# Page No. 22: 11 paragraphs
# Page No. 23: 11 paragraphs
# Page No. 24: 9 paragraphs
# Page No. 25: 12 paragraphs
# Page No. 26: 12 paragraphs
# Page No. 27: 11 paragraphs
# Page No. 28: 14 paragraphs
# Page No. 29: 13 paragraphs
# Page No. 30: 9 paragraphs
# Page No. 31: 11 paragraphs
# Page No. 32: 9 paragraphs
# Page No. 33: 10 paragraphs
# Page No. 34: 9 paragraphs
# Page No. 35: 9 paragraphs
# Page No. 36: 11 paragraphs
# Page No. 37: 19 paragraphs
# Page No. 38: 16 paragraphs
# Page No. 39: 17 paragraphs
# Page No. 40: 16 paragraphs
# Page No. 41: 14 paragraphs
# Page No. 42: 14 paragraphs
# Page No. 43: 13 paragraphs
# Page No. 44: 11 paragraphs
# Page No. 45: 10 paragraphs
# Page No. 46: 9 paragraphs
# Page No. 47: 10 paragraphs
# Page No. 48: 18 paragraphs
# Page No. 49: 14 paragraphs
# Page No. 50: 12 paragraphs
# Page No. 51: 45 paragraphs
# Page No. 52: 15 paragraphs
# Page No. 53: 16 paragraphs
# Page No. 54: 15 paragraphs
# Page No. 55: 15 paragraphs
# Page No. 56: 16 paragraphs
# Page No. 57: 15 paragraphs
# Page No. 58: 10 paragraphs
# Page No. 59: 17 paragraphs
# Page No. 60: 14 paragraphs
# Page No. 61: 22 paragraphs
# Page No. 62: 16 paragraphs
# Page No. 63: 12 paragraphs
# Page No. 64: 17 paragraphs
# Page No. 65: 15 paragraphs
# Page No. 66: 11 paragraphs
# Page No. 67: 12 paragraphs
# Page No. 68: 13 paragraphs
# Page No. 69: 20 paragraphs
# Page No. 70: 19 paragraphs
# Page No. 71: 18 paragraphs
# Page No. 72: 14 paragraphs
# Page No. 73: 16 paragraphs
# Page No. 74: 9 paragraphs
# Page No. 75: 9 paragraphs
# Page No. 76: 14 paragraphs
# Page No. 77: 18 paragraphs
# Page No. 78: 16 paragraphs
# Page No. 79: 11 paragraphs
# Page No. 80: 14 paragraphs
# Page No. 81: 13 paragraphs
# Page No. 82: 10 paragraphs
# Page No. 83: 11 paragraphs
# Page No. 84: 12 paragraphs
# Page No. 85: 13 paragraphs
# Page No. 86: 16 paragraphs
# Page No. 87: 11 paragraphs
# Page No. 88: 11 paragraphs
# Page No. 89: 9 paragraphs
# Page No. 90: 11 paragraphs
# Page No. 91: 9 paragraphs
# Page No. 92: 10 paragraphs
# Page No. 93: 13 paragraphs
# Page No. 94: 8 paragraphs

# %%
lotr1Clean = cleanText(lotr1Raw, 'Chapter 1')
lotr2Clean = cleanText(lotr2Raw, '')
lotr3Clean = cleanText(lotr3Raw, 'battle in the West')
lotr1Clean = lotr1Clean +lotr2Clean + lotr3Clean
hobbitClean = cleanText(hobbitRaw, 'Chapter I')
silmarillionClean = cleanText(silmarillionRaw, 'Christopher Tolkien')

# %% [markdown]
# ### Save text to .js files

# %%
with open('lotr.js', 'w', encoding='utf-8') as f:
    f.write(f'const lotr = {lotr1Clean}\n\n')
    f.write('module.exports = lotr;')
with open('hobbit.js', 'w', encoding='utf-8') as f:
    f.write(f'const hobbit = {hobbitClean}\n\n')
    f.write('module.exports = hobbit;')
with open('silmarillion.js', 'w', encoding='utf-8') as f:
    f.write(f'const silmarillion = {silmarillionClean}\n\n')
    f.write('module.exports = silmarillion;')
